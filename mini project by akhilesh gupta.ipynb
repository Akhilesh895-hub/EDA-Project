# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.shape
# Out:
# (545, 13)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df['price'].value_counts()
# Out:
# price
# 4200000    17
# 3500000    17
# 4900000    12
# 5250000     9
# 5600000     9
#            ..
# 2135000     1
# 1960000     1
# 1855000     1
# 1820000     1
# 1767150     1
# Name: count, Length: 219, dtype: int64

# %%
df['mainroad'].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
x = df['price']
y1 = df['area']
plt.figure(figsize=(13,5))
plt.title('HOUSING:-price vs area')
plt.xlabel('price')
plt.ylabel('area')
plt.plot(x,y1, color='r')
plt.show()

# %%
x = df['price']
y2 = df['bedrooms']
plt.figure(figsize=(12,5))
plt.title('HOUSING:-price vs bedrooms')
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.plot(x,y2, color='k', label='price vs bedroom')
plt.legend()
plt.show()

# %%
x = df['price']
y2 = df['bedrooms']
y3 = df['bathrooms']
y4 = df['stories']

plt.figure(figsize=(14,6))
plt.title('HOUSING:-price vs bedrooms, bathrooms & stories')
plt.xlabel('price')
plt.xticks(np.arange(1,8,1))
plt.yticks(np.arange(1,8,1))
plt.ylabel('bedrooms, bathrooms & stories')
plt.plot(x,y2, color='k')
plt.plot(x,y3, color='r')
plt.plot(x,y4, color='c')
plt.grid()
plt.show()

# %%
x = df['price']
y5 = df['guestroom']
y6 = df['airconditioning']
y7 = df['basement']
y8 = df['parking']
y9 = df['prefarea']

plt.figure(figsize=(14,6))
plt.title('HOUSING:-price vs facilities')
plt.xlabel('price')
plt.ylabel('guestroom, airconditioning, basement, parking & prefarea')
plt.plot(x,y5, color='k')
plt.plot(x,y6, color='r')
plt.plot(x,y7, color='c')
plt.plot(x,y8, color='y')
plt.plot(x,y9, color='g')
plt.grid()
plt.show()

# %%
x = df['price']
y1 = df['area']
y2 = df['bedrooms']
y3 = df['bathrooms']
y4 = df['stories']
y5 = df['guestroom']
y6 = df['airconditioning']
y7 = df['basement']
y8 = df['parking']
y9 = df['prefarea']

plt.figure(figsize=(14,6))
plt.xlabel('price')
plt.ylabel('accomodities')
plt.xticks(np.arange(1,8,1))
plt.yticks(np.arange(1,8,1))


plt.scatter(x,y1, color='orange')
plt.scatter(x,y2, color='k')
plt.scatter(x,y3, color='hotpink')
plt.scatter(x,y4, color='violet')
plt.scatter(x,y5, color='c')
plt.scatter(x,y6, color='pink')
plt.scatter(x,y7, color='r')
plt.scatter(x,y8, color='y')
plt.scatter(x,y9, color='g')

plt.legend(['area', 'bedrooms', 'bathrooms', 'stories', 'guestroom', 'airconditioning', 'basement', 'parking', 'prefarea'])
plt.show()

# %%
top = df.head()
print('FIRST 5 ROWS OF DATA:-\n',top)
# Out:
# FIRST 5 ROWS OF DATA:-
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
bot = df.tail()
print('LAST 5 ROWS OF DATA:-\n',bot)
# Out:
# LAST 5 ROWS OF DATA:-
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x = df['price']
y1 = df['area']
y2 = df['bedrooms']
y3 = df['bathrooms']
y4 = df['stories']

fig = plt.figure(figsize=(19,10))
fig.add_subplot(projection='3d')
plt.xlabel('price')
plt.ylabel('accomodities')

plt.plot(x,y1, color='orange')
plt.plot(x,y2, color='k')
plt.plot(x,y3, color='hotpink')
plt.plot(x,y4, color='violet')


plt.legend(['area', 'bedrooms', 'bathrooms', 'stories', 'guestroom', 'airconditioning', 'basement', 'parking', 'prefarea'])
plt.show()

# %%
x = df['mainroad']
y1 = df['price']

plt.figure(figsize=(13,5))
plt.title('HOUSING')
plt.xlabel('mainroad')
plt.ylabel('price')
plt.bar(x,y1, color='r')
plt.show()

# %%
x = df['mainroad']
y1 = df['price']
y2 = df['parking']

plt.figure(figsize=(13,5))
plt.title('HOUSING')
plt.xlabel('mainroad')
plt.ylabel('price')
plt.bar(x,y1, color='r')
plt.bar(x,y2, color='k')
plt.show()

# %%
df = pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
sns.histplot(df)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.histplot(df['price'])
plt.title('price')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df['area'], color='r', bins=30)
plt.title('area')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(df['stories'], color='r', bins=25)
plt.title('stories')
plt.grid()
plt.show()

# %%
sns.kdeplot(df)
plt.show()

# %%
sns.kdeplot(df['price'])
plt.show()

# %%
sns.kdeplot(df['area'], fill=True, color='b')
plt.show()

# %%
sns.distplot(df['price'])
plt.show
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13276\2841126887.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df['price'], color='c', hist=True,  bins=25)
plt.show
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13276\3229239038.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], color='c', hist=True,  bins=25)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df['price'], color='k', hist=False, kde=True, bins=25)
plt.show
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13276\1194390482.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], color='k', hist=False, kde=True, bins=25)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df['area'], color='hotpink', hist=False, kde=True, vertical=True)
plt.show
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13276\1398351336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'], color='hotpink', hist=False, kde=True, vertical=True)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(df['price'], color='k', hist=True, kde=False)
plt.show
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13276\2094834771.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], color='k', hist=True, kde=False)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(df['price'], color='g')
plt.show()
